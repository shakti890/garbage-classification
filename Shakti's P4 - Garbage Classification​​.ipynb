# %%
# !pip install tensorflow==2.15 
# !pip install gradio

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Rescaling, GlobalAveragePooling2D
from tensorflow.keras.applications import EfficientNetV2B2
from tensorflow.keras import layers, callbacks
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import confusion_matrix, classification_report
import gradio as gr
# Out:
# Requirement already satisfied: tensorflow==2.15 in d:\jupyter notebook\lib\site-packages (2.15.0)
# Requirement already satisfied: tensorflow-intel==2.15.0 in d:\jupyter notebook\lib\site-packages (from tensorflow==2.15) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in d:\jupyter notebook\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15) (2.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in d:\jupyter notebook\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in d:\jupyter notebook\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in d:\jupyter notebook\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\jupyter notebook\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in d:\jupyter notebook\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in d:\jupyter notebook\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in d:\jupyter notebook\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in d:\jupyter notebook\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\jupyter notebook\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15) (3.4.0)
# Requirement already satisfied: packaging in d:\jupyter notebook\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in d:\jupyter notebook\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15) (4.25.8)
# Requirement already satisfied: setuptools in d:\jupyter notebook\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in d:\jupyter notebook\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\jupyter notebook\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\jupyter notebook\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15) (4.13.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in d:\jupyter notebook\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in d:\jupyter notebook\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\jupyter notebook\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15) (1.73.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in d:\jupyter notebook\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in d:\jupyter notebook\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in d:\jupyter notebook\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\jupyter notebook\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow==2.15) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in d:\jupyter notebook\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15) (2.40.3)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in d:\jupyter notebook\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15) (1.2.2)
# Requirement already satisfied: markdown>=2.6.8 in d:\jupyter notebook\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\jupyter notebook\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\jupyter notebook\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\jupyter notebook\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\jupyter notebook\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\jupyter notebook\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\jupyter notebook\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\jupyter notebook\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\jupyter notebook\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\jupyter notebook\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\jupyter notebook\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in d:\jupyter notebook\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\jupyter notebook\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\jupyter notebook\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\jupyter notebook\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15) (3.3.1)
# Requirement already satisfied: gradio in d:\jupyter notebook\lib\site-packages (5.34.2)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in d:\jupyter notebook\lib\site-packages (from gradio) (22.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in d:\jupyter notebook\lib\site-packages (from gradio) (4.9.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in d:\jupyter notebook\lib\site-packages (from gradio) (0.115.12)
# Requirement already satisfied: ffmpy in d:\jupyter notebook\lib\site-packages (from gradio) (0.6.0)
# Requirement already satisfied: gradio-client==1.10.3 in d:\jupyter notebook\lib\site-packages (from gradio) (1.10.3)
# Requirement already satisfied: groovy~=0.1 in d:\jupyter notebook\lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx>=0.24.1 in d:\jupyter notebook\lib\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.28.1 in d:\jupyter notebook\lib\site-packages (from gradio) (0.33.0)
# Requirement already satisfied: jinja2<4.0 in d:\jupyter notebook\lib\site-packages (from gradio) (3.1.2)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in d:\jupyter notebook\lib\site-packages (from gradio) (2.1.1)
# Requirement already satisfied: numpy<3.0,>=1.0 in d:\jupyter notebook\lib\site-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in d:\jupyter notebook\lib\site-packages (from gradio) (3.10.18)
# Requirement already satisfied: packaging in d:\jupyter notebook\lib\site-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in d:\jupyter notebook\lib\site-packages (from gradio) (2.2.3)
# Requirement already satisfied: pillow<12.0,>=8.0 in d:\jupyter notebook\lib\site-packages (from gradio) (9.4.0)
# Requirement already satisfied: pydantic<2.12,>=2.0 in d:\jupyter notebook\lib\site-packages (from gradio) (2.11.7)
# Requirement already satisfied: pydub in d:\jupyter notebook\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in d:\jupyter notebook\lib\site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in d:\jupyter notebook\lib\site-packages (from gradio) (6.0)
# Requirement already satisfied: ruff>=0.9.3 in d:\jupyter notebook\lib\site-packages (from gradio) (0.12.0)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in d:\jupyter notebook\lib\site-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in d:\jupyter notebook\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in d:\jupyter notebook\lib\site-packages (from gradio) (0.46.2)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in d:\jupyter notebook\lib\site-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in d:\jupyter notebook\lib\site-packages (from gradio) (0.16.0)
# Requirement already satisfied: typing-extensions~=4.0 in d:\jupyter notebook\lib\site-packages (from gradio) (4.13.2)
# Requirement already satisfied: uvicorn>=0.14.0 in d:\jupyter notebook\lib\site-packages (from gradio) (0.34.2)
# Requirement already satisfied: fsspec in d:\jupyter notebook\lib\site-packages (from gradio-client==1.10.3->gradio) (2025.5.1)
# Requirement already satisfied: websockets<16.0,>=10.0 in d:\jupyter notebook\lib\site-packages (from gradio-client==1.10.3->gradio) (15.0.1)
# Requirement already satisfied: idna>=2.8 in d:\jupyter notebook\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.4)
# Requirement already satisfied: sniffio>=1.1 in d:\jupyter notebook\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.2.0)
# Requirement already satisfied: certifi in d:\jupyter notebook\lib\site-packages (from httpx>=0.24.1->gradio) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in d:\jupyter notebook\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\jupyter notebook\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock in d:\jupyter notebook\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (3.18.0)
# Requirement already satisfied: requests in d:\jupyter notebook\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in d:\jupyter notebook\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (4.65.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\jupyter notebook\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\jupyter notebook\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in d:\jupyter notebook\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\jupyter notebook\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in d:\jupyter notebook\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in d:\jupyter notebook\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (0.4.1)
# Requirement already satisfied: click>=8.0.0 in d:\jupyter notebook\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.0.4)
# Requirement already satisfied: shellingham>=1.3.0 in d:\jupyter notebook\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in d:\jupyter notebook\lib\site-packages (from typer<1.0,>=0.12->gradio) (14.0.0)
# Requirement already satisfied: colorama in d:\jupyter notebook\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in d:\jupyter notebook\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\jupyter notebook\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\jupyter notebook\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.15.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\jupyter notebook\lib\site-packages (from requests->huggingface-hub>=0.28.1->gradio) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\jupyter notebook\lib\site-packages (from requests->huggingface-hub>=0.28.1->gradio) (1.26.16)
# Requirement already satisfied: mdurl~=0.1 in d:\jupyter notebook\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.0)

# %%
dataset_dir= r"C:\Users\ASUS\Desktop\archive\TrashType_Image_Dataset"
image_size = (124, 124)
batch_size = 32
seed = 42

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    dataset_dir,
    validation_split=0.2,
    subset="training",
    seed=seed,
    shuffle = True,
    image_size=image_size,
    batch_size=batch_size
)
# Out:
# Found 2527 files belonging to 6 classes.
# Using 2022 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
    dataset_dir,
    validation_split=0.2,
    subset="validation",
    seed=seed,
    shuffle = True,
    image_size=image_size,
    batch_size=batch_size
)
val_class= val_ds.class_names
# Out:
# Found 2527 files belonging to 6 classes.
# Using 505 files for validation.

# %%
# Get the total number of batches in the validation dataset
val_batches = tf.data.experimental.cardinality(val_ds)  

# Split the validation dataset into two equal parts:
# First half becomes the test dataset
test_ds = val_ds.take(val_batches // 2)  

# Second half remains as the validation dataset
val_dat = val_ds.skip(val_batches // 2)  

# Optimize test dataset by caching and prefetching to improve performance
test_ds_eval = test_ds.cache().prefetch(tf.data.AUTOTUNE)

# %%
print(train_ds.class_names)
print(val_class)
print(len(train_ds.class_names))
# Out:
# ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']
# ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']
# 6

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(12):
    ax = plt.subplot(4, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(train_ds.class_names[labels[i]])
    plt.axis("off")

# %%
def count_distribution(dataset, class_names):
    total = 0
    counts = {name: 0 for name in class_names}
    
    for _, labels in dataset:
        for label in labels.numpy():
            class_name = class_names[label]
            counts[class_name] += 1
            total += 1

    for k in counts:
        counts[k] = round((counts[k] / total) * 100, 2)  # Convert to percentage
    return counts

# %%
# Function to plot class distribution
def simple_bar_plot(dist, title):
    plt.bar(dist.keys(), dist.values(), color='cornflowerblue')
    plt.title(title)
    plt.ylabel('Percentage (%)')
    plt.xticks(rotation=45)
    plt.ylim(0, 100)
    plt.tight_layout()
    plt.show()

# %%
class_names = train_ds.class_names

# Get class distributions
train_dist = count_distribution(train_ds, class_names)
val_dist = count_distribution(val_ds, class_names)
test_dist = count_distribution(test_ds, class_names)
overall_dist = {}
for k in class_names:
    overall_dist[k] = round((train_dist[k] + val_dist[k]) / 2, 2)

print(train_dist)
print(val_dist)
print(test_dist)
print(overall_dist)
# Out:
# {'cardboard': 16.52, 'glass': 19.73, 'metal': 15.92, 'paper': 23.29, 'plastic': 19.44, 'trash': 5.09}
# {'cardboard': 13.66, 'glass': 20.2, 'metal': 17.43, 'paper': 24.36, 'plastic': 17.62, 'trash': 6.73}
# {'cardboard': 14.06, 'glass': 17.58, 'metal': 16.8, 'paper': 25.0, 'plastic': 19.14, 'trash': 7.42}
# {'cardboard': 15.09, 'glass': 19.96, 'metal': 16.68, 'paper': 23.82, 'plastic': 18.53, 'trash': 5.91}

# %%
# Show visualizations
simple_bar_plot(train_dist, "Training Set Class Distribution (%)")
simple_bar_plot(val_dist, "Validation Set Class Distribution (%)")
simple_bar_plot(test_dist, "Test Set Class Distribution (%)")
simple_bar_plot(overall_dist, "Overall Class Distribution (%)")

# %%
import numpy as np
from sklearn.utils.class_weight import compute_class_weight

# Count class occurrences and prepare label list
class_counts = {i: 0 for i in range(len(class_names))}
all_labels = []

for images, labels in train_ds:
    for label in labels.numpy():
        if isinstance(label, np.ndarray):  # handle one-hot encoded case
            label = np.argmax(label)
        class_counts[label] += 1
        all_labels.append(label)

# Compute class weights (index aligned)
class_weights_array = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(all_labels),  # use actual labels present in the data
    y=all_labels
)

# Create dictionary mapping class index to weight
class_weights = {i: w for i, w in zip(np.unique(all_labels), class_weights_array)}

# %%
print("Class Counts:", class_counts)
print("Class Weights:", class_weights)
# Out:
# Class Counts: {0: 334, 1: 399, 2: 322, 3: 471, 4: 393, 5: 103}
# Class Weights: {0: 1.0089820359281436, 1: 0.8446115288220551, 2: 1.046583850931677, 3: 0.7154989384288747, 4: 0.8575063613231552, 5: 3.2718446601941746}

# %%
#  Define data augmentation pipeline
data_augmentation = Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
    layers.RandomContrast(0.1),
])

# %%
#  Load the pretrained MobileNetV3Small model (without the top classification layer)
base_model = EfficientNetV2B2(include_top=False, input_shape=(124, 124, 3),include_preprocessing=True, weights='imagenet')


#  Freeze early layers (to retain general pretrained features)
base_model.trainable = True
for layer in base_model.layers[:100]:  # You can adjust this number
    layer.trainable = False

# %%
#  Build the final model
model = Sequential([
    layers.Input(shape=(124, 124, 3)),
    data_augmentation,
    base_model,
    GlobalAveragePooling2D(),
    layers.Dropout(0.3),
    layers.Dense(6, activation='softmax')  # Change to your number of classes
])

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Fix class_weights to reindex from 0
label_mapping = {label: idx for idx, label in enumerate(sorted(set(all_labels)))}
mapped_labels = [label_mapping[label] for label in all_labels]

from sklearn.utils.class_weight import compute_class_weight

class_weights_array = compute_class_weight(
    class_weight='balanced',
    classes=np.arange(len(label_mapping)),
    y=mapped_labels
)

class_weights = {i: w for i, w in enumerate(class_weights_array)}

# %%
# 📝 Summary (optional but useful)
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_2 (Sequential)   (None, 124, 124, 3)       0
#
#  efficientnetv2-b2 (Functio  (None, 4, 4, 1408)        8769374
#  nal)
#
#  global_average_pooling2d (  (None, 1408)              0
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1408)              0
#
#  dense (Dense)               (None, 6)                 8454
#
# =================================================================
# Total params: 8777828 (33.48 MB)
# Trainable params: 7974642 (30.42 MB)
# Non-trainable params: 803186 (3.06 MB)
# _________________________________________________________________

# %%
base_model.summary() # Print the architecture summary of the base model
# Out:
# Model: "efficientnetv2-b2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 124, 124, 3)]        0         []
#
#  rescaling_1 (Rescaling)     (None, 124, 124, 3)          0         ['input_2[0][0]']
#
#  normalization_1 (Normaliza  (None, 124, 124, 3)          0         ['rescaling_1[0][0]']
#  tion)
#
#  stem_conv (Conv2D)          (None, 62, 62, 32)           864       ['normalization_1[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 62, 62, 32)           128       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 62, 62, 32)           0         ['stem_bn[0][0]']
#  n)
#
#  block1a_project_conv (Conv  (None, 62, 62, 16)           4608      ['stem_activation[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 62, 62, 16)           64        ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1a_project_activation  (None, 62, 62, 16)           0         ['block1a_project_bn[0][0]']
#   (Activation)
#
#  block1b_project_conv (Conv  (None, 62, 62, 16)           2304      ['block1a_project_activation[0
#  2D)                                                                ][0]']
#
#  block1b_project_bn (BatchN  (None, 62, 62, 16)           64        ['block1b_project_conv[0][0]']
#  ormalization)
#
#  block1b_project_activation  (None, 62, 62, 16)           0         ['block1b_project_bn[0][0]']
#   (Activation)
#
#  block1b_drop (Dropout)      (None, 62, 62, 16)           0         ['block1b_project_activation[0
#                                                                     ][0]']
#
#  block1b_add (Add)           (None, 62, 62, 16)           0         ['block1b_drop[0][0]',
#                                                                      'block1a_project_activation[0
#                                                                     ][0]']
#
#  block2a_expand_conv (Conv2  (None, 31, 31, 64)           9216      ['block1b_add[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 31, 31, 64)           256       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 31, 31, 64)           0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_project_conv (Conv  (None, 31, 31, 32)           2048      ['block2a_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2a_project_bn (BatchN  (None, 31, 31, 32)           128       ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 31, 31, 128)          36864     ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 31, 31, 128)          512       ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 31, 31, 128)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_project_conv (Conv  (None, 31, 31, 32)           4096      ['block2b_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2b_project_bn (BatchN  (None, 31, 31, 32)           128       ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, 31, 31, 32)           0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, 31, 31, 32)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2  (None, 31, 31, 128)          36864     ['block2b_add[0][0]']
#  D)
#
#  block2c_expand_bn (BatchNo  (None, 31, 31, 128)          512       ['block2c_expand_conv[0][0]']
#  rmalization)
#
#  block2c_expand_activation   (None, 31, 31, 128)          0         ['block2c_expand_bn[0][0]']
#  (Activation)
#
#  block2c_project_conv (Conv  (None, 31, 31, 32)           4096      ['block2c_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2c_project_bn (BatchN  (None, 31, 31, 32)           128       ['block2c_project_conv[0][0]']
#  ormalization)
#
#  block2c_drop (Dropout)      (None, 31, 31, 32)           0         ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)           (None, 31, 31, 32)           0         ['block2c_drop[0][0]',
#                                                                      'block2b_add[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 16, 16, 128)          36864     ['block2c_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 16, 16, 128)          512       ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 16, 16, 128)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_project_conv (Conv  (None, 16, 16, 56)           7168      ['block3a_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3a_project_bn (BatchN  (None, 16, 16, 56)           224       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 16, 16, 224)          112896    ['block3a_project_bn[0][0]']
#  D)
#
#  block3b_expand_bn (BatchNo  (None, 16, 16, 224)          896       ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  block3b_expand_activation   (None, 16, 16, 224)          0         ['block3b_expand_bn[0][0]']
#  (Activation)
#
#  block3b_project_conv (Conv  (None, 16, 16, 56)           12544     ['block3b_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3b_project_bn (BatchN  (None, 16, 16, 56)           224       ['block3b_project_conv[0][0]']
#  ormalization)
#
#  block3b_drop (Dropout)      (None, 16, 16, 56)           0         ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)           (None, 16, 16, 56)           0         ['block3b_drop[0][0]',
#                                                                      'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2  (None, 16, 16, 224)          112896    ['block3b_add[0][0]']
#  D)
#
#  block3c_expand_bn (BatchNo  (None, 16, 16, 224)          896       ['block3c_expand_conv[0][0]']
#  rmalization)
#
#  block3c_expand_activation   (None, 16, 16, 224)          0         ['block3c_expand_bn[0][0]']
#  (Activation)
#
#  block3c_project_conv (Conv  (None, 16, 16, 56)           12544     ['block3c_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3c_project_bn (BatchN  (None, 16, 16, 56)           224       ['block3c_project_conv[0][0]']
#  ormalization)
#
#  block3c_drop (Dropout)      (None, 16, 16, 56)           0         ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)           (None, 16, 16, 56)           0         ['block3c_drop[0][0]',
#                                                                      'block3b_add[0][0]']
#
#  block4a_expand_conv (Conv2  (None, 16, 16, 224)          12544     ['block3c_add[0][0]']
#  D)
#
#  block4a_expand_bn (BatchNo  (None, 16, 16, 224)          896       ['block4a_expand_conv[0][0]']
#  rmalization)
#
#  block4a_expand_activation   (None, 16, 16, 224)          0         ['block4a_expand_bn[0][0]']
#  (Activation)
#
#  block4a_dwconv2 (Depthwise  (None, 8, 8, 224)            2016      ['block4a_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4a_bn (BatchNormaliza  (None, 8, 8, 224)            896       ['block4a_dwconv2[0][0]']
#  tion)
#
#  block4a_activation (Activa  (None, 8, 8, 224)            0         ['block4a_bn[0][0]']
#  tion)
#
#  block4a_se_squeeze (Global  (None, 224)                  0         ['block4a_activation[0][0]']
#  AveragePooling2D)
#
#  block4a_se_reshape (Reshap  (None, 1, 1, 224)            0         ['block4a_se_squeeze[0][0]']
#  e)
#
#  block4a_se_reduce (Conv2D)  (None, 1, 1, 14)             3150      ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)  (None, 1, 1, 224)            3360      ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multipl  (None, 8, 8, 224)            0         ['block4a_activation[0][0]',
#  y)                                                                  'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv  (None, 8, 8, 104)            23296     ['block4a_se_excite[0][0]']
#  2D)
#
#  block4a_project_bn (BatchN  (None, 8, 8, 104)            416       ['block4a_project_conv[0][0]']
#  ormalization)
#
#  block4b_expand_conv (Conv2  (None, 8, 8, 416)            43264     ['block4a_project_bn[0][0]']
#  D)
#
#  block4b_expand_bn (BatchNo  (None, 8, 8, 416)            1664      ['block4b_expand_conv[0][0]']
#  rmalization)
#
#  block4b_expand_activation   (None, 8, 8, 416)            0         ['block4b_expand_bn[0][0]']
#  (Activation)
#
#  block4b_dwconv2 (Depthwise  (None, 8, 8, 416)            3744      ['block4b_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4b_bn (BatchNormaliza  (None, 8, 8, 416)            1664      ['block4b_dwconv2[0][0]']
#  tion)
#
#  block4b_activation (Activa  (None, 8, 8, 416)            0         ['block4b_bn[0][0]']
#  tion)
#
#  block4b_se_squeeze (Global  (None, 416)                  0         ['block4b_activation[0][0]']
#  AveragePooling2D)
#
#  block4b_se_reshape (Reshap  (None, 1, 1, 416)            0         ['block4b_se_squeeze[0][0]']
#  e)
#
#  block4b_se_reduce (Conv2D)  (None, 1, 1, 26)             10842     ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)  (None, 1, 1, 416)            11232     ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multipl  (None, 8, 8, 416)            0         ['block4b_activation[0][0]',
#  y)                                                                  'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv  (None, 8, 8, 104)            43264     ['block4b_se_excite[0][0]']
#  2D)
#
#  block4b_project_bn (BatchN  (None, 8, 8, 104)            416       ['block4b_project_conv[0][0]']
#  ormalization)
#
#  block4b_drop (Dropout)      (None, 8, 8, 104)            0         ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)           (None, 8, 8, 104)            0         ['block4b_drop[0][0]',
#                                                                      'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2  (None, 8, 8, 416)            43264     ['block4b_add[0][0]']
#  D)
#
#  block4c_expand_bn (BatchNo  (None, 8, 8, 416)            1664      ['block4c_expand_conv[0][0]']
#  rmalization)
#
#  block4c_expand_activation   (None, 8, 8, 416)            0         ['block4c_expand_bn[0][0]']
#  (Activation)
#
#  block4c_dwconv2 (Depthwise  (None, 8, 8, 416)            3744      ['block4c_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4c_bn (BatchNormaliza  (None, 8, 8, 416)            1664      ['block4c_dwconv2[0][0]']
#  tion)
#
#  block4c_activation (Activa  (None, 8, 8, 416)            0         ['block4c_bn[0][0]']
#  tion)
#
#  block4c_se_squeeze (Global  (None, 416)                  0         ['block4c_activation[0][0]']
#  AveragePooling2D)
#
#  block4c_se_reshape (Reshap  (None, 1, 1, 416)            0         ['block4c_se_squeeze[0][0]']
#  e)
#
#  block4c_se_reduce (Conv2D)  (None, 1, 1, 26)             10842     ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)  (None, 1, 1, 416)            11232     ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multipl  (None, 8, 8, 416)            0         ['block4c_activation[0][0]',
#  y)                                                                  'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv  (None, 8, 8, 104)            43264     ['block4c_se_excite[0][0]']
#  2D)
#
#  block4c_project_bn (BatchN  (None, 8, 8, 104)            416       ['block4c_project_conv[0][0]']
#  ormalization)
#
#  block4c_drop (Dropout)      (None, 8, 8, 104)            0         ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)           (None, 8, 8, 104)            0         ['block4c_drop[0][0]',
#                                                                      'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2  (None, 8, 8, 416)            43264     ['block4c_add[0][0]']
#  D)
#
#  block4d_expand_bn (BatchNo  (None, 8, 8, 416)            1664      ['block4d_expand_conv[0][0]']
#  rmalization)
#
#  block4d_expand_activation   (None, 8, 8, 416)            0         ['block4d_expand_bn[0][0]']
#  (Activation)
#
#  block4d_dwconv2 (Depthwise  (None, 8, 8, 416)            3744      ['block4d_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4d_bn (BatchNormaliza  (None, 8, 8, 416)            1664      ['block4d_dwconv2[0][0]']
#  tion)
#
#  block4d_activation (Activa  (None, 8, 8, 416)            0         ['block4d_bn[0][0]']
#  tion)
#
#  block4d_se_squeeze (Global  (None, 416)                  0         ['block4d_activation[0][0]']
#  AveragePooling2D)
#
#  block4d_se_reshape (Reshap  (None, 1, 1, 416)            0         ['block4d_se_squeeze[0][0]']
#  e)
#
#  block4d_se_reduce (Conv2D)  (None, 1, 1, 26)             10842     ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)  (None, 1, 1, 416)            11232     ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multipl  (None, 8, 8, 416)            0         ['block4d_activation[0][0]',
#  y)                                                                  'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv  (None, 8, 8, 104)            43264     ['block4d_se_excite[0][0]']
#  2D)
#
#  block4d_project_bn (BatchN  (None, 8, 8, 104)            416       ['block4d_project_conv[0][0]']
#  ormalization)
#
#  block4d_drop (Dropout)      (None, 8, 8, 104)            0         ['block4d_project_bn[0][0]']
#
#  block4d_add (Add)           (None, 8, 8, 104)            0         ['block4d_drop[0][0]',
#                                                                      'block4c_add[0][0]']
#
#  block5a_expand_conv (Conv2  (None, 8, 8, 624)            64896     ['block4d_add[0][0]']
#  D)
#
#  block5a_expand_bn (BatchNo  (None, 8, 8, 624)            2496      ['block5a_expand_conv[0][0]']
#  rmalization)
#
#  block5a_expand_activation   (None, 8, 8, 624)            0         ['block5a_expand_bn[0][0]']
#  (Activation)
#
#  block5a_dwconv2 (Depthwise  (None, 8, 8, 624)            5616      ['block5a_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block5a_bn (BatchNormaliza  (None, 8, 8, 624)            2496      ['block5a_dwconv2[0][0]']
#  tion)
#
#  block5a_activation (Activa  (None, 8, 8, 624)            0         ['block5a_bn[0][0]']
#  tion)
#
#  block5a_se_squeeze (Global  (None, 624)                  0         ['block5a_activation[0][0]']
#  AveragePooling2D)
#
#  block5a_se_reshape (Reshap  (None, 1, 1, 624)            0         ['block5a_se_squeeze[0][0]']
#  e)
#
#  block5a_se_reduce (Conv2D)  (None, 1, 1, 26)             16250     ['block5a_se_reshape[0][0]']
#
#  block5a_se_expand (Conv2D)  (None, 1, 1, 624)            16848     ['block5a_se_reduce[0][0]']
#
#  block5a_se_excite (Multipl  (None, 8, 8, 624)            0         ['block5a_activation[0][0]',
#  y)                                                                  'block5a_se_expand[0][0]']
#
#  block5a_project_conv (Conv  (None, 8, 8, 120)            74880     ['block5a_se_excite[0][0]']
#  2D)
#
#  block5a_project_bn (BatchN  (None, 8, 8, 120)            480       ['block5a_project_conv[0][0]']
#  ormalization)
#
#  block5b_expand_conv (Conv2  (None, 8, 8, 720)            86400     ['block5a_project_bn[0][0]']
#  D)
#
#  block5b_expand_bn (BatchNo  (None, 8, 8, 720)            2880      ['block5b_expand_conv[0][0]']
#  rmalization)
#
#  block5b_expand_activation   (None, 8, 8, 720)            0         ['block5b_expand_bn[0][0]']
#  (Activation)
#
#  block5b_dwconv2 (Depthwise  (None, 8, 8, 720)            6480      ['block5b_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block5b_bn (BatchNormaliza  (None, 8, 8, 720)            2880      ['block5b_dwconv2[0][0]']
#  tion)
#
#  block5b_activation (Activa  (None, 8, 8, 720)            0         ['block5b_bn[0][0]']
#  tion)
#
#  block5b_se_squeeze (Global  (None, 720)                  0         ['block5b_activation[0][0]']
#  AveragePooling2D)
#
#  block5b_se_reshape (Reshap  (None, 1, 1, 720)            0         ['block5b_se_squeeze[0][0]']
#  e)
#
#  block5b_se_reduce (Conv2D)  (None, 1, 1, 30)             21630     ['block5b_se_reshape[0][0]']
#
#  block5b_se_expand (Conv2D)  (None, 1, 1, 720)            22320     ['block5b_se_reduce[0][0]']
#
#  block5b_se_excite (Multipl  (None, 8, 8, 720)            0         ['block5b_activation[0][0]',
#  y)                                                                  'block5b_se_expand[0][0]']
#
#  block5b_project_conv (Conv  (None, 8, 8, 120)            86400     ['block5b_se_excite[0][0]']
#  2D)
#
#  block5b_project_bn (BatchN  (None, 8, 8, 120)            480       ['block5b_project_conv[0][0]']
#  ormalization)
#
#  block5b_drop (Dropout)      (None, 8, 8, 120)            0         ['block5b_project_bn[0][0]']
#
#  block5b_add (Add)           (None, 8, 8, 120)            0         ['block5b_drop[0][0]',
#                                                                      'block5a_project_bn[0][0]']
#
#  block5c_expand_conv (Conv2  (None, 8, 8, 720)            86400     ['block5b_add[0][0]']
#  D)
#
#  block5c_expand_bn (BatchNo  (None, 8, 8, 720)            2880      ['block5c_expand_conv[0][0]']
#  rmalization)
#
#  block5c_expand_activation   (None, 8, 8, 720)            0         ['block5c_expand_bn[0][0]']
#  (Activation)
#
#  block5c_dwconv2 (Depthwise  (None, 8, 8, 720)            6480      ['block5c_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block5c_bn (BatchNormaliza  (None, 8, 8, 720)            2880      ['block5c_dwconv2[0][0]']
#  tion)
#
#  block5c_activation (Activa  (None, 8, 8, 720)            0         ['block5c_bn[0][0]']
#  tion)
#
#  block5c_se_squeeze (Global  (None, 720)                  0         ['block5c_activation[0][0]']
#  AveragePooling2D)
#
#  block5c_se_reshape (Reshap  (None, 1, 1, 720)            0         ['block5c_se_squeeze[0][0]']
#  e)
#
#  block5c_se_reduce (Conv2D)  (None, 1, 1, 30)             21630     ['block5c_se_reshape[0][0]']
#
#  block5c_se_expand (Conv2D)  (None, 1, 1, 720)            22320     ['block5c_se_reduce[0][0]']
#
#  block5c_se_excite (Multipl  (None, 8, 8, 720)            0         ['block5c_activation[0][0]',
#  y)                                                                  'block5c_se_expand[0][0]']
#
#  block5c_project_conv (Conv  (None, 8, 8, 120)            86400     ['block5c_se_excite[0][0]']
#  2D)
#
#  block5c_project_bn (BatchN  (None, 8, 8, 120)            480       ['block5c_project_conv[0][0]']
#  ormalization)
#
#  block5c_drop (Dropout)      (None, 8, 8, 120)            0         ['block5c_project_bn[0][0]']
#
#  block5c_add (Add)           (None, 8, 8, 120)            0         ['block5c_drop[0][0]',
#                                                                      'block5b_add[0][0]']
#
#  block5d_expand_conv (Conv2  (None, 8, 8, 720)            86400     ['block5c_add[0][0]']
#  D)
#
#  block5d_expand_bn (BatchNo  (None, 8, 8, 720)            2880      ['block5d_expand_conv[0][0]']
#  rmalization)
#
#  block5d_expand_activation   (None, 8, 8, 720)            0         ['block5d_expand_bn[0][0]']
#  (Activation)
#
#  block5d_dwconv2 (Depthwise  (None, 8, 8, 720)            6480      ['block5d_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block5d_bn (BatchNormaliza  (None, 8, 8, 720)            2880      ['block5d_dwconv2[0][0]']
#  tion)
#
#  block5d_activation (Activa  (None, 8, 8, 720)            0         ['block5d_bn[0][0]']
#  tion)
#
#  block5d_se_squeeze (Global  (None, 720)                  0         ['block5d_activation[0][0]']
#  AveragePooling2D)
#
#  block5d_se_reshape (Reshap  (None, 1, 1, 720)            0         ['block5d_se_squeeze[0][0]']
#  e)
#
#  block5d_se_reduce (Conv2D)  (None, 1, 1, 30)             21630     ['block5d_se_reshape[0][0]']
#
#  block5d_se_expand (Conv2D)  (None, 1, 1, 720)            22320     ['block5d_se_reduce[0][0]']
#
#  block5d_se_excite (Multipl  (None, 8, 8, 720)            0         ['block5d_activation[0][0]',
#  y)                                                                  'block5d_se_expand[0][0]']
#
#  block5d_project_conv (Conv  (None, 8, 8, 120)            86400     ['block5d_se_excite[0][0]']
#  2D)
#
#  block5d_project_bn (BatchN  (None, 8, 8, 120)            480       ['block5d_project_conv[0][0]']
#  ormalization)
#
#  block5d_drop (Dropout)      (None, 8, 8, 120)            0         ['block5d_project_bn[0][0]']
#
#  block5d_add (Add)           (None, 8, 8, 120)            0         ['block5d_drop[0][0]',
#                                                                      'block5c_add[0][0]']
#
#  block5e_expand_conv (Conv2  (None, 8, 8, 720)            86400     ['block5d_add[0][0]']
#  D)
#
#  block5e_expand_bn (BatchNo  (None, 8, 8, 720)            2880      ['block5e_expand_conv[0][0]']
#  rmalization)
# ...
#  block6g_se_squeeze (Global  (None, 1248)                 0         ['block6g_activation[0][0]']
#  AveragePooling2D)
#
#  block6g_se_reshape (Reshap  (None, 1, 1, 1248)           0         ['block6g_se_squeeze[0][0]']
#  e)
#
#  block6g_se_reduce (Conv2D)  (None, 1, 1, 52)             64948     ['block6g_se_reshape[0][0]']
#
#  block6g_se_expand (Conv2D)  (None, 1, 1, 1248)           66144     ['block6g_se_reduce[0][0]']
#
#  block6g_se_excite (Multipl  (None, 4, 4, 1248)           0         ['block6g_activation[0][0]',
#  y)                                                                  'block6g_se_expand[0][0]']
#
#  block6g_project_conv (Conv  (None, 4, 4, 208)            259584    ['block6g_se_excite[0][0]']
#  2D)
#
#  block6g_project_bn (BatchN  (None, 4, 4, 208)            832       ['block6g_project_conv[0][0]']
#  ormalization)
#
#  block6g_drop (Dropout)      (None, 4, 4, 208)            0         ['block6g_project_bn[0][0]']
#
#  block6g_add (Add)           (None, 4, 4, 208)            0         ['block6g_drop[0][0]',
#                                                                      'block6f_add[0][0]']
#
#  block6h_expand_conv (Conv2  (None, 4, 4, 1248)           259584    ['block6g_add[0][0]']
#  D)
#
#  block6h_expand_bn (BatchNo  (None, 4, 4, 1248)           4992      ['block6h_expand_conv[0][0]']
#  rmalization)
#
#  block6h_expand_activation   (None, 4, 4, 1248)           0         ['block6h_expand_bn[0][0]']
#  (Activation)
#
#  block6h_dwconv2 (Depthwise  (None, 4, 4, 1248)           11232     ['block6h_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6h_bn (BatchNormaliza  (None, 4, 4, 1248)           4992      ['block6h_dwconv2[0][0]']
#  tion)
#
#  block6h_activation (Activa  (None, 4, 4, 1248)           0         ['block6h_bn[0][0]']
#  tion)
#
#  block6h_se_squeeze (Global  (None, 1248)                 0         ['block6h_activation[0][0]']
#  AveragePooling2D)
#
#  block6h_se_reshape (Reshap  (None, 1, 1, 1248)           0         ['block6h_se_squeeze[0][0]']
#  e)
#
#  block6h_se_reduce (Conv2D)  (None, 1, 1, 52)             64948     ['block6h_se_reshape[0][0]']
#
#  block6h_se_expand (Conv2D)  (None, 1, 1, 1248)           66144     ['block6h_se_reduce[0][0]']
#
#  block6h_se_excite (Multipl  (None, 4, 4, 1248)           0         ['block6h_activation[0][0]',
#  y)                                                                  'block6h_se_expand[0][0]']
#
#  block6h_project_conv (Conv  (None, 4, 4, 208)            259584    ['block6h_se_excite[0][0]']
#  2D)
#
#  block6h_project_bn (BatchN  (None, 4, 4, 208)            832       ['block6h_project_conv[0][0]']
#  ormalization)
#
#  block6h_drop (Dropout)      (None, 4, 4, 208)            0         ['block6h_project_bn[0][0]']
#
#  block6h_add (Add)           (None, 4, 4, 208)            0         ['block6h_drop[0][0]',
#                                                                      'block6g_add[0][0]']
#
#  block6i_expand_conv (Conv2  (None, 4, 4, 1248)           259584    ['block6h_add[0][0]']
#  D)
#
#  block6i_expand_bn (BatchNo  (None, 4, 4, 1248)           4992      ['block6i_expand_conv[0][0]']
#  rmalization)
#
#  block6i_expand_activation   (None, 4, 4, 1248)           0         ['block6i_expand_bn[0][0]']
#  (Activation)
#
#  block6i_dwconv2 (Depthwise  (None, 4, 4, 1248)           11232     ['block6i_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6i_bn (BatchNormaliza  (None, 4, 4, 1248)           4992      ['block6i_dwconv2[0][0]']
#  tion)
#
#  block6i_activation (Activa  (None, 4, 4, 1248)           0         ['block6i_bn[0][0]']
#  tion)
#
#  block6i_se_squeeze (Global  (None, 1248)                 0         ['block6i_activation[0][0]']
#  AveragePooling2D)
#
#  block6i_se_reshape (Reshap  (None, 1, 1, 1248)           0         ['block6i_se_squeeze[0][0]']
#  e)
#
#  block6i_se_reduce (Conv2D)  (None, 1, 1, 52)             64948     ['block6i_se_reshape[0][0]']
#
#  block6i_se_expand (Conv2D)  (None, 1, 1, 1248)           66144     ['block6i_se_reduce[0][0]']
#
#  block6i_se_excite (Multipl  (None, 4, 4, 1248)           0         ['block6i_activation[0][0]',
#  y)                                                                  'block6i_se_expand[0][0]']
#
#  block6i_project_conv (Conv  (None, 4, 4, 208)            259584    ['block6i_se_excite[0][0]']
#  2D)
#
#  block6i_project_bn (BatchN  (None, 4, 4, 208)            832       ['block6i_project_conv[0][0]']
#  ormalization)
#
#  block6i_drop (Dropout)      (None, 4, 4, 208)            0         ['block6i_project_bn[0][0]']
#
#  block6i_add (Add)           (None, 4, 4, 208)            0         ['block6i_drop[0][0]',
#                                                                      'block6h_add[0][0]']
#
#  block6j_expand_conv (Conv2  (None, 4, 4, 1248)           259584    ['block6i_add[0][0]']
#  D)
#
#  block6j_expand_bn (BatchNo  (None, 4, 4, 1248)           4992      ['block6j_expand_conv[0][0]']
#  rmalization)
#
#  block6j_expand_activation   (None, 4, 4, 1248)           0         ['block6j_expand_bn[0][0]']
#  (Activation)
#
#  block6j_dwconv2 (Depthwise  (None, 4, 4, 1248)           11232     ['block6j_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6j_bn (BatchNormaliza  (None, 4, 4, 1248)           4992      ['block6j_dwconv2[0][0]']
#  tion)
#
#  block6j_activation (Activa  (None, 4, 4, 1248)           0         ['block6j_bn[0][0]']
#  tion)
#
#  block6j_se_squeeze (Global  (None, 1248)                 0         ['block6j_activation[0][0]']
#  AveragePooling2D)
#
#  block6j_se_reshape (Reshap  (None, 1, 1, 1248)           0         ['block6j_se_squeeze[0][0]']
#  e)
#
#  block6j_se_reduce (Conv2D)  (None, 1, 1, 52)             64948     ['block6j_se_reshape[0][0]']
#
#  block6j_se_expand (Conv2D)  (None, 1, 1, 1248)           66144     ['block6j_se_reduce[0][0]']
#
#  block6j_se_excite (Multipl  (None, 4, 4, 1248)           0         ['block6j_activation[0][0]',
#  y)                                                                  'block6j_se_expand[0][0]']
#
#  block6j_project_conv (Conv  (None, 4, 4, 208)            259584    ['block6j_se_excite[0][0]']
#  2D)
#
#  block6j_project_bn (BatchN  (None, 4, 4, 208)            832       ['block6j_project_conv[0][0]']
#  ormalization)
#
#  block6j_drop (Dropout)      (None, 4, 4, 208)            0         ['block6j_project_bn[0][0]']
#
#  block6j_add (Add)           (None, 4, 4, 208)            0         ['block6j_drop[0][0]',
#                                                                      'block6i_add[0][0]']
#
#  top_conv (Conv2D)           (None, 4, 4, 1408)           292864    ['block6j_add[0][0]']
#
#  top_bn (BatchNormalization  (None, 4, 4, 1408)           5632      ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 4, 4, 1408)           0         ['top_bn[0][0]']
#  )
#
# ==================================================================================================
# Total params: 8769374 (33.45 MB)
# Trainable params: 7966188 (30.39 MB)
# Non-trainable params: 803186 (3.06 MB)
# __________________________________________________________________________________________________

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10
)

acc = history.history['accuracy']          # Extract training accuracy from history
val_acc = history.history['val_accuracy']  # Extract validation accuracy from history
loss = history.history['loss']             # Extract training loss from history
val_loss = history.history['val_loss']     # Extract validation loss from history

epochs_range = range(len(acc))             # Define range for epochs based on accuracy length

plt.figure(figsize=(10,8))                 # Set overall figure size for visualization

plt.subplot(1,2,1)                         # Create first subplot (1 row, 2 columns, position 1)
plt.plot(epochs_range, acc, label='Training Accuracy')       # Plot training accuracy
plt.plot(epochs_range, val_acc, label='Validation Accuracy') # Plot validation accuracy
plt.legend(loc='lower right')              # Place legend in lower-right corner
plt.title('Training vs Validation Accuracy') # Add title for accuracy plot

plt.subplot(1,2,2)                         # Create second subplot (1 row, 2 columns, position 2)
plt.plot(epochs_range, loss, label='Training Loss')         # Plot training loss
plt.plot(epochs_range, val_loss, label='Validation Loss')   # Plot validation loss
plt.legend(loc='upper right')              # Place legend in upper-right corner
plt.title('Training vs Validation Loss')   # Add title for loss plot

plt.show()                                 # Display the plots
# Out:
# Epoch 1/10
# WARNING:tensorflow:From D:\Jupyter notebook\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From D:\Jupyter notebook\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 64/64 [==============================] - 99s 757ms/step - loss: 1.5347 - accuracy: 0.3996 - val_loss: 1.1160 - val_accuracy: 0.6475
# Epoch 2/10
# 64/64 [==============================] - 44s 694ms/step - loss: 0.9280 - accuracy: 0.7033 - val_loss: 0.7410 - val_accuracy: 0.7901
# Epoch 3/10
# 64/64 [==============================] - 44s 693ms/step - loss: 0.6166 - accuracy: 0.8081 - val_loss: 0.5614 - val_accuracy: 0.8277
# Epoch 4/10
# 64/64 [==============================] - 44s 690ms/step - loss: 0.4514 - accuracy: 0.8487 - val_loss: 0.4511 - val_accuracy: 0.8416
# Epoch 5/10
# 64/64 [==============================] - 44s 694ms/step - loss: 0.3302 - accuracy: 0.8956 - val_loss: 0.4212 - val_accuracy: 0.8515
# Epoch 6/10
# 64/64 [==============================] - 45s 696ms/step - loss: 0.2958 - accuracy: 0.9016 - val_loss: 0.3780 - val_accuracy: 0.8614
# Epoch 7/10
# 64/64 [==============================] - 44s 689ms/step - loss: 0.2292 - accuracy: 0.9283 - val_loss: 0.3484 - val_accuracy: 0.8752
# Epoch 8/10
# 64/64 [==============================] - 45s 696ms/step - loss: 0.1709 - accuracy: 0.9491 - val_loss: 0.3273 - val_accuracy: 0.8851
# Epoch 9/10
# 64/64 [==============================] - 44s 691ms/step - loss: 0.1500 - accuracy: 0.9565 - val_loss: 0.3058 - val_accuracy: 0.8931
# Epoch 10/10
# 64/64 [==============================] - 43s 674ms/step - loss: 0.1258 - accuracy: 0.9614 - val_loss: 0.3000 - val_accuracy: 0.8851

# %%
loss, accuracy = model.evaluate(test_ds_eval)
print(f'Test accuracy is{accuracy:.4f}, Test loss is {loss:.4f}')
# Out:
# 8/8 [==============================] - 2s 246ms/step - loss: 0.2537 - accuracy: 0.9023
# Test accuracy is0.9023, Test loss is 0.2537

# %%
# Extract true labels from all batches in the test dataset
y_true = np.concatenate([y.numpy() for x, y in test_ds_eval], axis=0)  # Convert Tensor labels to NumPy array and concatenate them

# Get predictions as probabilities from the model
y_pred_probs = model.predict(test_ds_eval)  # Predict class probabilities for each sample in the test dataset

# Convert probabilities to predicted class indices
y_pred = np.argmax(y_pred_probs, axis=1)  # Select the class with the highest probability for each sample

# Compute the confusion matrix to evaluate classification performance
cm = confusion_matrix(y_true, y_pred)  # Generate confusion matrix comparing true labels to predicted labels

# Print metrics to assess model performance
print(cm)  # Display confusion matrix
print(classification_report(y_true, y_pred))  # Print precision, recall, and F1-score for each class
# Out:
# 8/8 [==============================] - 6s 237ms/step
# [[26  0  0  3  0  0]
#  [ 0 44  9  0  1  0]
#  [ 0  0 42  0  0  0]
#  [ 2  0  0 73  0  1]
#  [ 0  3  1  0 33  5]
#  [ 0  0  0  0  0 13]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.91        29
#            1       0.94      0.81      0.87        54
#            2       0.81      1.00      0.89        42
#            3       0.96      0.96      0.96        76
#            4       0.97      0.79      0.87        42
#            5       0.68      1.00      0.81        13
#
#     accuracy                           0.90       256
#    macro avg       0.88      0.91      0.89       256
# weighted avg       0.91      0.90      0.90       256

# %%
plt.figure(figsize=(10,8))  # Set figure size for better visualization

sns.heatmap(cm, annot=True, fmt='d',  # Create heatmap using confusion matrix
            xticklabels=class_names,  # Set class names for x-axis (predicted labels)
            yticklabels=class_names,  # Set class names for y-axis (true labels)
            cmap='Blues')  # Use a blue colormap for better contrast

plt.xlabel('Predicted')  # Label x-axis as Predicted classes
plt.ylabel('True')  # Label y-axis as True classes
plt.title('Confusion Matrix')  # Add title to the heatmap
plt.show()  # Display the plot

# %%
# Extract class names from the training dataset
class_names = train_ds.class_names  

# Take one batch of images and labels from the test dataset for evaluation
for images, labels in test_ds_eval.take(1):  

    # Generate predictions for the batch of images
    predictions = model.predict(images)  

    # Get the predicted class index for each image
    pred_labels = tf.argmax(predictions, axis=1)  

    # Loop through the first 8 images in the batch
    for i in range(8):  
        plt.imshow(images[i].numpy().astype("uint8"))  # Convert and display image
        plt.title(f"True: {class_names[labels[i]]}, Pred: {class_names[pred_labels[i]]}")  # Show actual and predicted class
        plt.axis("off")  # Hide axes for better visualization
        plt.show()  # Display the image with title
# Out:
# 1/1 [==============================] - 4s 4s/step

# %%
# Save model in Keras format with architecture, weights, and training configuration
model.save('Effiicientnetv2b2.keras')

# Load your Keras model
model = tf.keras.models.load_model('Effiicientnetv2b2.keras')

# %%
# !pip install gradio
# Out:
# Requirement already satisfied: gradio in d:\jupyter notebook\lib\site-packages (5.34.2)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in d:\jupyter notebook\lib\site-packages (from gradio) (22.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in d:\jupyter notebook\lib\site-packages (from gradio) (4.9.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in d:\jupyter notebook\lib\site-packages (from gradio) (0.115.12)
# Requirement already satisfied: ffmpy in d:\jupyter notebook\lib\site-packages (from gradio) (0.6.0)
# Requirement already satisfied: gradio-client==1.10.3 in d:\jupyter notebook\lib\site-packages (from gradio) (1.10.3)
# Requirement already satisfied: groovy~=0.1 in d:\jupyter notebook\lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx>=0.24.1 in d:\jupyter notebook\lib\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.28.1 in d:\jupyter notebook\lib\site-packages (from gradio) (0.33.0)
# Requirement already satisfied: jinja2<4.0 in d:\jupyter notebook\lib\site-packages (from gradio) (3.1.2)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in d:\jupyter notebook\lib\site-packages (from gradio) (2.1.1)
# Requirement already satisfied: numpy<3.0,>=1.0 in d:\jupyter notebook\lib\site-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in d:\jupyter notebook\lib\site-packages (from gradio) (3.10.18)
# Requirement already satisfied: packaging in d:\jupyter notebook\lib\site-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in d:\jupyter notebook\lib\site-packages (from gradio) (2.2.3)
# Requirement already satisfied: pillow<12.0,>=8.0 in d:\jupyter notebook\lib\site-packages (from gradio) (9.4.0)
# Requirement already satisfied: pydantic<2.12,>=2.0 in d:\jupyter notebook\lib\site-packages (from gradio) (2.11.7)
# Requirement already satisfied: pydub in d:\jupyter notebook\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in d:\jupyter notebook\lib\site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in d:\jupyter notebook\lib\site-packages (from gradio) (6.0)
# Requirement already satisfied: ruff>=0.9.3 in d:\jupyter notebook\lib\site-packages (from gradio) (0.12.0)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in d:\jupyter notebook\lib\site-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in d:\jupyter notebook\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in d:\jupyter notebook\lib\site-packages (from gradio) (0.46.2)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in d:\jupyter notebook\lib\site-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in d:\jupyter notebook\lib\site-packages (from gradio) (0.16.0)
# Requirement already satisfied: typing-extensions~=4.0 in d:\jupyter notebook\lib\site-packages (from gradio) (4.13.2)
# Requirement already satisfied: uvicorn>=0.14.0 in d:\jupyter notebook\lib\site-packages (from gradio) (0.34.2)
# Requirement already satisfied: fsspec in d:\jupyter notebook\lib\site-packages (from gradio-client==1.10.3->gradio) (2025.5.1)
# Requirement already satisfied: websockets<16.0,>=10.0 in d:\jupyter notebook\lib\site-packages (from gradio-client==1.10.3->gradio) (15.0.1)
# Requirement already satisfied: idna>=2.8 in d:\jupyter notebook\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.4)
# Requirement already satisfied: sniffio>=1.1 in d:\jupyter notebook\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.2.0)
# Requirement already satisfied: certifi in d:\jupyter notebook\lib\site-packages (from httpx>=0.24.1->gradio) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in d:\jupyter notebook\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\jupyter notebook\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock in d:\jupyter notebook\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (3.18.0)
# Requirement already satisfied: requests in d:\jupyter notebook\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in d:\jupyter notebook\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (4.65.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\jupyter notebook\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\jupyter notebook\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in d:\jupyter notebook\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\jupyter notebook\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in d:\jupyter notebook\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in d:\jupyter notebook\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (0.4.1)
# Requirement already satisfied: click>=8.0.0 in d:\jupyter notebook\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.0.4)
# Requirement already satisfied: shellingham>=1.3.0 in d:\jupyter notebook\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in d:\jupyter notebook\lib\site-packages (from typer<1.0,>=0.12->gradio) (14.0.0)
# Requirement already satisfied: colorama in d:\jupyter notebook\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in d:\jupyter notebook\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\jupyter notebook\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\jupyter notebook\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.15.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\jupyter notebook\lib\site-packages (from requests->huggingface-hub>=0.28.1->gradio) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\jupyter notebook\lib\site-packages (from requests->huggingface-hub>=0.28.1->gradio) (1.26.16)
# Requirement already satisfied: mdurl~=0.1 in d:\jupyter notebook\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.0)

# %%
from tensorflow.keras.applications.efficientnet_v2 import preprocess_input

# %%
def classify_image(img):  
    # Resize image to 124x124 pixels (Note: Comment says 128x128, but code resizes to 124x124)
    img = img.resize((124, 124))  
    
    # Convert image to a NumPy array with float32 dtype
    img_array = np.array(img, dtype=np.float32)  
    img_array = preprocess_input(img_array)
    
    # Expand dimensions to match model input shape (adds a batch dimension)
    img_array = np.expand_dims(img_array, axis=0)  
    
    # Make a prediction using the trained model
    prediction = model.predict(img_array)  
    
    # Get the index of the highest predicted probability
    predicted_class_index = np.argmax(prediction)  
    
    # Map the predicted index to its corresponding class name
    predicted_class_name = class_names[predicted_class_index]  
    
    # Extract confidence score (probability of the predicted class)
    confidence = prediction[0][predicted_class_index]  
    
    # Return formatted prediction result with confidence score
    return f"Predicted: {predicted_class_name} (Confidence: {confidence:.2f})"

# %%
iface = gr.Interface(  
    fn=classify_image,  # Function to classify image using the trained model  
    inputs=gr.Image(type="pil"),  # Accepts input as a PIL image  
    outputs="text"  # Outputs prediction as text  
)  

# Launch the interface  
iface.launch()  # Start the Gradio interface for user interaction
# Out:
# * Running on local URL:  http://127.0.0.1:7867
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7867/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "D:\Jupyter notebook\Lib\site-packages\uvicorn\protocols\http\h11_impl.py", line 403, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Jupyter notebook\Lib\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Jupyter notebook\Lib\site-packages\fastapi\applications.py", line 1054, in __call__
#     await super().__call__(scope, receive, send)
#   File "D:\Jupyter notebook\Lib\site-packages\starlette\applications.py", line 112, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "D:\Jupyter notebook\Lib\site-packages\starlette\middleware\errors.py", line 187, in __call__
#     raise exc
#   File "D:\Jupyter notebook\Lib\site-packages\starlette\middleware\errors.py", line 165, in __call__
#     await self.app(scope, receive, _send)
#   File "D:\Jupyter notebook\Lib\site-packages\gradio\route_utils.py", line 834, in __call__
#     await self.app(scope, receive, send)
#   File "D:\Jupyter notebook\Lib\site-packages\starlette\middleware\exceptions.py", line 62, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "D:\Jupyter notebook\Lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "D:\Jupyter notebook\Lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "D:\Jupyter notebook\Lib\site-packages\starlette\routing.py", line 714, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "D:\Jupyter notebook\Lib\site-packages\starlette\routing.py", line 734, in app
#     await route.handle(scope, receive, send)
#   File "D:\Jupyter notebook\Lib\site-packages\starlette\routing.py", line 288, in handle
#     await self.app(scope, receive, send)
#   File "D:\Jupyter notebook\Lib\site-packages\starlette\routing.py", line 76, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "D:\Jupyter notebook\Lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "D:\Jupyter notebook\Lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "D:\Jupyter notebook\Lib\site-packages\starlette\routing.py", line 74, in app
#     await response(scope, receive, send)
#   File "D:\Jupyter notebook\Lib\site-packages\starlette\responses.py", line 359, in __call__
#     await self._handle_simple(send, send_header_only)
#   File "D:\Jupyter notebook\Lib\site-packages\starlette\responses.py", line 388, in _handle_simple
#     await send({"type": "http.response.body", "body": chunk, "more_body": more_body})
#   File "D:\Jupyter notebook\Lib\site-packages\starlette\_exception_handler.py", line 39, in sender
#     await send(message)
#   File "D:\Jupyter notebook\Lib\site-packages\starlette\_exception_handler.py", line 39, in sender
#     await send(message)
#   File "D:\Jupyter notebook\Lib\site-packages\starlette\middleware\errors.py", line 162, in _send
#     await send(message)
#   File "D:\Jupyter notebook\Lib\site-packages\uvicorn\protocols\http\h11_impl.py", line 507, in send
#     output = self.conn.send(event=h11.EndOfMessage())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Jupyter notebook\Lib\site-packages\h11\_connection.py", line 538, in send
#     data_list = self.send_with_data_passthrough(event)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Jupyter notebook\Lib\site-packages\h11\_connection.py", line 571, in send_with_data_passthrough
#     writer(event, data_list.append)
#   File "D:\Jupyter notebook\Lib\site-packages\h11\_writers.py", line 67, in __call__
#     self.send_eom(event.headers, write)
#   File "D:\Jupyter notebook\Lib\site-packages\h11\_writers.py", line 96, in send_eom
#     raise LocalProtocolError("Too little data for declared Content-Length")
# h11._util.LocalProtocolError: Too little data for declared Content-Length
# 1/1 [==============================] - 0s 48ms/step

# %% [markdown]
# # Conclusion:
#
# Garbage classification plays a vital role in promoting environmental sustainability, reducing pollution, and improving waste management efficiency. By correctly sorting waste into categories like biodegradable, recyclable, hazardous, and non-recyclable, we can enhance recycling processes, conserve natural resources, and minimize landfill usage. Implementing proper garbage classification at individual, community, and industrial levels is essential for creating cleaner cities and ensuring a healthier planet for future generations.
